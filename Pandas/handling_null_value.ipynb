# %%
import pandas as pd
import numpy as np
df=pd.read_csv("expense_data_1.csv")
df
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# Account             0
# Category            0
# Subcategory       277
# Note                4
# INR                 0
# Income/Expense      0
# Note.1            277
# Amount              0
# Currency            0
# Account.1           0
# dtype: int64

# %%
#delete null value 
print(df.dropna(how='all'))
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
print(df.dropna(thresh=1))
print(df.dropna(subset=['Subcategory','Note.1']))
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          NaN
# 1      3/2/2022 10:11  CUB - online payment           Other          NaN
# 2      3/1/2022 19:50  CUB - online payment            Food          NaN
# 3      3/1/2022 18:56  CUB - online payment  Transportation          NaN
# 4      3/1/2022 18:22  CUB - online payment            Food          NaN
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          NaN
# 273  11/22/2021 14:16  CUB - online payment            Food          NaN
# 274  11/21/2021 17:07  CUB - online payment  Transportation          NaN
# 275  11/21/2021 15:50  CUB - online payment            Food          NaN
# 276  11/21/2021 13:30  CUB - online payment           Other          NaN
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
#replace null value /NaN value by any  value 
print(df.replace(np.nan,"hii"))
# Out:
#                  Date               Account        Category Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food         hii
# 1      3/2/2022 10:11  CUB - online payment           Other         hii
# 2      3/1/2022 19:50  CUB - online payment            Food         hii
# 3      3/1/2022 18:56  CUB - online payment  Transportation         hii
# 4      3/1/2022 18:22  CUB - online payment            Food         hii
# ..                ...                   ...             ...         ...
# 272  11/22/2021 14:16  CUB - online payment            Food         hii
# 273  11/22/2021 14:16  CUB - online payment            Food         hii
# 274  11/21/2021 17:07  CUB - online payment  Transportation         hii
# 275  11/21/2021 15:50  CUB - online payment            Food         hii
# 276  11/21/2021 13:30  CUB - online payment           Other         hii
#
#                    Note     INR Income/Expense Note.1  Amount Currency  \
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            277 non-null    object
#  1   Account         277 non-null    object
#  2   Category        277 non-null    object
#  3   Subcategory     0 non-null      float64
#  4   Note            273 non-null    object
#  5   INR             277 non-null    float64
#  6   Income/Expense  277 non-null    object
#  7   Note.1          0 non-null      float64
#  8   Amount          277 non-null    float64
#  9   Currency        277 non-null    object
#  10  Account.1       277 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 23.9+ KB

# %%
df['Subcategory']=df['Subcategory'].replace(np.nan,0)

# %%
df
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          0.0
# 1      3/2/2022 10:11  CUB - online payment           Other          0.0
# 2      3/1/2022 19:50  CUB - online payment            Food          0.0
# 3      3/1/2022 18:56  CUB - online payment  Transportation          0.0
# 4      3/1/2022 18:22  CUB - online payment            Food          0.0
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          0.0
# 273  11/22/2021 14:16  CUB - online payment            Food          0.0
# 274  11/21/2021 17:07  CUB - online payment  Transportation          0.0
# 275  11/21/2021 15:50  CUB - online payment            Food          0.0
# 276  11/21/2021 13:30  CUB - online payment           Other          0.0
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
df.drop('Note.1',axis=1)
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          0.0
# 1      3/2/2022 10:11  CUB - online payment           Other          0.0
# 2      3/1/2022 19:50  CUB - online payment            Food          0.0
# 3      3/1/2022 18:56  CUB - online payment  Transportation          0.0
# 4      3/1/2022 18:22  CUB - online payment            Food          0.0
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          0.0
# 273  11/22/2021 14:16  CUB - online payment            Food          0.0
# 274  11/21/2021 17:07  CUB - online payment  Transportation          0.0
# 275  11/21/2021 15:50  CUB - online payment            Food          0.0
# 276  11/21/2021 13:30  CUB - online payment           Other          0.0
#
#                    Note     INR Income/Expense  Amount Currency  Account.1
# ...

# %%
# for categorical data use upper fill and lower fill
#use fillna () method
data1={'id':[10,20,300],'name':['ansar ','nan','ashu'],'age':[21,22,20]}
print(data1)
# Out:
# {'id': [10, 20, 300], 'name': ['ansar ', 'nan', 'ashu'], 'age': [21, 22, 20]}

# %%
data2=pd.DataFrame(data1)
data3=data2.ffill(axis=1)
print(data3)
# Out:
#     id    name  age
# 0   10  ansar    21
# 1   20     nan   22
# 2  300    ashu   20

# %%
 # col transformation using loc 
df.loc[df['Account.1']>200,"Account.2"]="midum"
df.loc[df['Account.1']>100 ,'Account.2']="high"
df.loc[df['Account.1']<=100,"Account.2"]="low"
print(df)
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          0.0
# 1      3/2/2022 10:11  CUB - online payment           Other          0.0
# 2      3/1/2022 19:50  CUB - online payment            Food          0.0
# 3      3/1/2022 18:56  CUB - online payment  Transportation          0.0
# 4      3/1/2022 18:22  CUB - online payment            Food          0.0
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          0.0
# 273  11/22/2021 14:16  CUB - online payment            Food          0.0
# 274  11/21/2021 17:07  CUB - online payment  Transportation          0.0
# 275  11/21/2021 15:50  CUB - online payment            Food          0.0
# 276  11/21/2021 13:30  CUB - online payment           Other          0.0
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
df["INR Percentage"]=(df['INR']/100)*20
print(df)
# Out:
#                  Date               Account        Category  Subcategory  \
# 0      3/2/2022 10:11  CUB - online payment            Food          0.0
# 1      3/2/2022 10:11  CUB - online payment           Other          0.0
# 2      3/1/2022 19:50  CUB - online payment            Food          0.0
# 3      3/1/2022 18:56  CUB - online payment  Transportation          0.0
# 4      3/1/2022 18:22  CUB - online payment            Food          0.0
# ..                ...                   ...             ...          ...
# 272  11/22/2021 14:16  CUB - online payment            Food          0.0
# 273  11/22/2021 14:16  CUB - online payment            Food          0.0
# 274  11/21/2021 17:07  CUB - online payment  Transportation          0.0
# 275  11/21/2021 15:50  CUB - online payment            Food          0.0
# 276  11/21/2021 13:30  CUB - online payment           Other          0.0
#
#                    Note     INR Income/Expense  Note.1  Amount Currency  \
# ...

# %%
#map Function 
months={"months":["janaury","febray","march","april","may","june"]}
mon=pd.DataFrame(months)
print(mon)
# Out:
#     months
# 0  janaury
# 1   febray
# 2    march
# 3    april
# 4      may
# 5     june

# %%
def addcol_to_substring(value):
    return value[:3]
mon['short_month']=mon['months'].map(addcol_to_substring)
print(mon)
# Out:
#     months short_month
# 0  janaury         jan
# 1   febray         feb
# 2    march         mar
# 3    april         apr
# 4      may         may
# 5     june         jun
